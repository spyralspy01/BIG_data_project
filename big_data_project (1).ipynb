# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score,accuracy_score

# %%
# importing data set make sure it is on the same file
df=pd.read_csv('processedNegative.csv',header=None)
df.head()
# Out:
#                                     0     \
# 0  How unhappy  some dogs like it though
#
#                                                 1     \
# 0  talking to my over driver about where I'm goin...
#
#                                                 2     \
# 0  Does anybody know if the Rand's likely to fall...
#
#                                          3     \
# 0  I miss going to gigs in Liverpool unhappy
#
#                                             4     \
# 0  There isnt a new Riverdale tonight ? unhappy
#
#                                                 5     \
# 0  it's that A*dy guy from pop Asia and then the ...
#
#                                                 6     \
# 0  Who's that chair you're sitting in? Is this ho...
#
#                                             7     \
# 0  don't like how jittery caffeine makes me sad
#
#                                                 8     \
# 0  My area's not on the list unhappy  think I'll ...
#
#                                      9     ...  \
# 0  I want fun plans this weekend unhappy   ...
#
#                                                 1107  \
# 0  and yet if parents invest in child's emotional...
#
#                                                 1108  \
# 0  YG should have sent them to MCD. I want to see...
#
#                                1109                1110  \
# 0  i want more orientation unhappy   unhappy  they not
#
#                                                 1111  \
# 0  YG should have sent them to MCD. I want to see...
#
#                                                 1112                     1113  \
# 0  wish knock out lang talaga for the new school ...  i miss so much unhappy
#
#             1114                                         1115  \
# 0  Same unhappy   Hi instant message your friend  friend lang
#
#                            1116
# 0   hindi close friend? unhappy
#
# [1 rows x 1117 columns]

# %%
df = df.T
df
# Out:
#                                                       0
# 0                 How unhappy  some dogs like it though
# 1     talking to my over driver about where I'm goin...
# 2     Does anybody know if the Rand's likely to fall...
# 3            I miss going to gigs in Liverpool unhappy
# 4         There isnt a new Riverdale tonight ? unhappy
# ...                                                 ...
# 1112  wish knock out lang talaga for the new school ...
# 1113                            i miss so much unhappy
# 1114                                      Same unhappy
# 1115        Hi instant message your friend  friend lang
# 1116                        hindi close friend? unhappy
#
# [1117 rows x 1 columns]

# %%
df.columns = ['tweets']
df
# Out:
#                                                  tweets
# 0                 How unhappy  some dogs like it though
# 1     talking to my over driver about where I'm goin...
# 2     Does anybody know if the Rand's likely to fall...
# 3            I miss going to gigs in Liverpool unhappy
# 4         There isnt a new Riverdale tonight ? unhappy
# ...                                                 ...
# 1112  wish knock out lang talaga for the new school ...
# 1113                            i miss so much unhappy
# 1114                                      Same unhappy
# 1115        Hi instant message your friend  friend lang
# 1116                        hindi close friend? unhappy
#
# [1117 rows x 1 columns]

# %%
# importing test data set 
dft=pd.read_csv('processedPositive.csv',header=None)
dft.head()
# Out:
#                                      0         1     \
# 0  An inspiration in all aspects: Fashion   fitness
#
#                                                2     \
# 0   beauty and personality. :)KISSES TheFashionIcon
#
#                                                 3     \
# 0  Apka Apna Awam Ka Channel Frankline Tv Aam Adm...
#
#                                                 4     \
# 0  Beautiful album from  the greatest unsung guit...
#
#                                                 5     \
# 0  Good luck to Rich riding for great project in ...
#
#                                       6     \
# 0  Omg he... kissed... him crying with joy
#
#                                              7             8             9     \
# 0  happy anniv ming and papi!!!!! love love happy  thanks happy  C'mon Tweeps
#
#    ...                                               1176  \
# 0  ...  $ES_F $SPY  Bulls are just relentless  happy  ...
#
#                                                 1177  \
# 0  Thanks for the recent follow Happy to connect ...
#
#                                                 1178  \
# 0  Thanks for the recent follow Happy to connect ...
#
#                                                 1179  \
# 0  Thanks for the recent follow Happy to connect ...
#
#                                        1180  \
# 0  you know that the problem still exist :D
#
#                                                 1181  \
# 0  Thanks for the recent follow Happy to connect ...
#
#                                     1182  \
# 0  - top engaged members this week happy
#
#                                                 1183  \
# 0  ngam to  weeks left for cadet pilot exam cryin...
#
#                                       1184  \
# 0  Great! You're welcome Josh happy  ^Adam
#
#                                                 1185
# 0  Sixth spot not applicable Team! Higher pa! :)K...
#
# [1 rows x 1186 columns]

# %%
dft = dft.T
dft
# Out:
#                                                       0
# 0                An inspiration in all aspects: Fashion
# 1                                               fitness
# 2       beauty and personality. :)KISSES TheFashionIcon
# 3     Apka Apna Awam Ka Channel Frankline Tv Aam Adm...
# 4     Beautiful album from  the greatest unsung guit...
# ...                                                 ...
# 1181  Thanks for the recent follow Happy to connect ...
# 1182              - top engaged members this week happy
# 1183  ngam to  weeks left for cadet pilot exam cryin...
# 1184            Great! You're welcome Josh happy  ^Adam
# 1185  Sixth spot not applicable Team! Higher pa! :)K...
#
# [1186 rows x 1 columns]

# %%
dft.columns = ['tweets']
dft
# Out:
#                                                  tweets
# 0                An inspiration in all aspects: Fashion
# 1                                               fitness
# 2       beauty and personality. :)KISSES TheFashionIcon
# 3     Apka Apna Awam Ka Channel Frankline Tv Aam Adm...
# 4     Beautiful album from  the greatest unsung guit...
# ...                                                 ...
# 1181  Thanks for the recent follow Happy to connect ...
# 1182              - top engaged members this week happy
# 1183  ngam to  weeks left for cadet pilot exam cryin...
# 1184            Great! You're welcome Josh happy  ^Adam
# 1185  Sixth spot not applicable Team! Higher pa! :)K...
#
# [1186 rows x 1 columns]

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117 entries, 0 to 1116
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  1116 non-null   object
# dtypes: object(1)
# memory usage: 49.7+ KB

# %%
dft.info()
dft.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1186 entries, 0 to 1185
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  1183 non-null   object
# dtypes: object(1)
# memory usage: 50.8+ KB
#                                                    tweets
# count                                                1183
# unique                                               1001
# top     Thanks for the recent follow Happy to connect ...
# freq                                                   34

# %%
df=df.applymap(str)
print(df.dtypes)
# Out:
# tweets    object
# dtype: object

# %%
dft=dft.applymap(str)
print(dft.dtypes)
# Out:
# tweets    object
# dtype: object

# %%
#converting all the strings into lower case letters.
df_lower = df["tweets"].map(lambda x: x.lower())
#converting all the strings into lower case letters.
dft_lower = dft["tweets"].map(lambda x: x.lower())

# %%
df_lower_tweets = pd.DataFrame(df_lower)
dft_lower_tweets = pd.DataFrame(dft_lower)

# %%
df_lower_tweets
# Out:
#                                                  tweets
# 0                 how unhappy  some dogs like it though
# 1     talking to my over driver about where i'm goin...
# 2     does anybody know if the rand's likely to fall...
# 3            i miss going to gigs in liverpool unhappy
# 4         there isnt a new riverdale tonight ? unhappy
# ...                                                 ...
# 1112  wish knock out lang talaga for the new school ...
# 1113                            i miss so much unhappy
# 1114                                      same unhappy
# 1115        hi instant message your friend  friend lang
# 1116                        hindi close friend? unhappy
#
# [1117 rows x 1 columns]

# %%
data = df_lower_tweets
datat = dft_lower_tweets

# %%
# i tried removing special characters(punctuation marks which are listed below) from dataframe
data['tweets'] = data['tweets'].str.replace(r"[!$%&'()*+,-./:;<=>?[\]^_`{|}~]", '',regex=True)
data
# i tried removing special characters from dataframe
datat['tweets'] = datat['tweets'].str.replace(r"[!$%&'()*+,-./:;<=>?[\]^_`{|}~]", '',regex=True)
datat
# Out:
#                                                  tweets
# 0                 an inspiration in all aspects fashion
# 1                                               fitness
# 2          beauty and personality kisses thefashionicon
# 3     apka apna awam ka channel frankline tv aam adm...
# 4     beautiful album from  the greatest unsung guit...
# ...                                                 ...
# 1181  thanks for the recent follow happy to connect ...
# 1182                top engaged members this week happy
# 1183  ngam to  weeks left for cadet pilot exam cryin...
# 1184               great youre welcome josh happy  adam
# 1185  sixth spot not applicable team higher pa kisse...
#
# [1186 rows x 1 columns]

# %%
# # tried removing @USER
# data['welsh tweets'] = data['welsh tweets'].str.replace(r'@user', '')

# %%
# # tried removing URL
# data['welsh tweets'] = data['welsh tweets'].str.replace(r'url', '')

# %%
# tried dropping duplicate elements
# df_final = df_final.drop_duplicates()
# df_final

# %%
# data_final = data.drop_duplicates()
# data_final

# %%
# datat_final = data.drop_duplicates()
# datat_final

# %%
df['index'] = 0
df
# Out:
#                                                  tweets  index
# 0                 How unhappy  some dogs like it though      0
# 1     talking to my over driver about where I'm goin...      0
# 2     Does anybody know if the Rand's likely to fall...      0
# 3            I miss going to gigs in Liverpool unhappy       0
# 4         There isnt a new Riverdale tonight ? unhappy       0
# ...                                                 ...    ...
# 1112  wish knock out lang talaga for the new school ...      0
# 1113                            i miss so much unhappy       0
# 1114                                      Same unhappy       0
# 1115        Hi instant message your friend  friend lang      0
# 1116                        hindi close friend? unhappy      0
#
# [1117 rows x 2 columns]

# %%
dft['index'] = 1
dft
# Out:
#                                                  tweets  index
# 0                An inspiration in all aspects: Fashion      1
# 1                                               fitness      1
# 2       beauty and personality. :)KISSES TheFashionIcon      1
# 3     Apka Apna Awam Ka Channel Frankline Tv Aam Adm...      1
# 4     Beautiful album from  the greatest unsung guit...      1
# ...                                                 ...    ...
# 1181  Thanks for the recent follow Happy to connect ...      1
# 1182              - top engaged members this week happy      1
# 1183  ngam to  weeks left for cadet pilot exam cryin...      1
# 1184            Great! You're welcome Josh happy  ^Adam      1
# 1185  Sixth spot not applicable Team! Higher pa! :)K...      1
#
# [1186 rows x 2 columns]

# %%
frames = [df,dft]
data = pd.concat(frames)
data
# Out:
#                                                  tweets  index
# 0                 How unhappy  some dogs like it though      0
# 1     talking to my over driver about where I'm goin...      0
# 2     Does anybody know if the Rand's likely to fall...      0
# 3            I miss going to gigs in Liverpool unhappy       0
# 4         There isnt a new Riverdale tonight ? unhappy       0
# ...                                                 ...    ...
# 1181  Thanks for the recent follow Happy to connect ...      1
# 1182              - top engaged members this week happy      1
# 1183  ngam to  weeks left for cadet pilot exam cryin...      1
# 1184            Great! You're welcome Josh happy  ^Adam      1
# 1185  Sixth spot not applicable Team! Higher pa! :)K...      1
#
# [2303 rows x 2 columns]

# %%
# train set
vectorizer = CountVectorizer(min_df=2,stop_words='english',max_features=4000)
features = vectorizer.fit_transform(data['tweets'])
indexs = data['index']

# %%
x_train, x_test, y_train, y_test = train_test_split(features,indexs, test_size=0.2,random_state=10)

# %%
naivebayes_bernoulli = BernoulliNB()
naivebayes_bernoulli.fit(x_train.toarray(), y_train)
# Out:
# BernoulliNB()

# %%
naivebayes_multinomial = MultinomialNB()
naivebayes_multinomial.fit(x_train.toarray(), y_train)
# Out:
# MultinomialNB()

# %%
lr = LogisticRegression(max_iter=2000)
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
nbbpredict = naivebayes_bernoulli.predict(x_test.toarray())

# %%
nbmpredict = naivebayes_multinomial.predict(x_test.toarray())

# %%
lrpredict = lr.predict(x_test)

# %%
x_prob = lr.predict_proba(x_test)

# %%
##### validation accuracy ########

# %%
print(metrics.classification_report(y_test,nbmpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       222
#            1       0.90      0.89      0.89       239
#
#     accuracy                           0.89       461
#    macro avg       0.89      0.89      0.89       461
# weighted avg       0.89      0.89      0.89       461

# %%
print(metrics.classification_report(y_test,nbbpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87       222
#            1       0.87      0.90      0.89       239
#
#     accuracy                           0.88       461
#    macro avg       0.88      0.88      0.88       461
# weighted avg       0.88      0.88      0.88       461

# %%
from sklearn.metrics import f1_score,recall_score
print(metrics.classification_report(y_test,lrpredict))
print(roc_auc_score(y_test, x_prob[:, 1]))
print(accuracy_score(y_test,lrpredict))
print(recall_score(y_test,lrpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.89       222
#            1       0.86      0.96      0.91       239
#
#     accuracy                           0.90       461
#    macro avg       0.91      0.90      0.90       461
# weighted avg       0.90      0.90      0.90       461
#
# 0.9697312375136644
# 0.8980477223427332
# 0.9623430962343096
